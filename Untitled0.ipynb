# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoBLl/MineriaDeDatos/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minería de Datos

# %% [markdown]
# ## Primer parcial

# %% [markdown]
# ### Introducción

# %% [markdown]
# #### Conceptos

# %% [markdown]
# **¿Qué es Minería de datos?**
#
# Consta de analizar grandes volúmenes de datos para descubrir patrones y tendencias ocultas. Identifica comportamientos repetitivos y predecir resultados futuros.

# %% [markdown]
# #### Ciencia de datos

# %% [markdown]
# Help and Documentation in iPython

# %%
#La función help nos muestra la ayuda
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
#Otra forma de obtener ayuda es con ?
len?

# %%
#Ejemplo de ayuda en una lista
L = [1,2,3]
L.insert?

# %%
#Otro ejemplo de ayuda
L?

# %%
#Ejemplo con una función con Docstring
def square(a):
  """Return the square of a."""
  return a**2

# %%
##
help(square)
# Out:
# Help on function square in module __main__:
#
# square(a)
#     Return the square of a.

# %%
square??

# %%
L.insert
