# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoBLl/MineriaDeDatos/blob/main/Copia_de_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minería de Datos

# %% [markdown]
# ## Primer parcial

# %% [markdown]
# ### Introducción

# %% [markdown]
# #### Conceptos

# %% [markdown]
# Consta de analizar grandes volúmenes de datos para descubrir patrones y tendencias ocultas que permiten convertir datos brutos en conocimiento útil para la toma de desiciones.

# %% [markdown]
# #### Ciencia de datos
